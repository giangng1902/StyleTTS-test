# %%
dir = r"C:/Users/Nguyen Giang/Documents/ngochuyen_RVC"
output_dir = r'C:/ngochuyen_RVC_24k'

# %%
from pydub import AudioSegment
import os
from pathlib import Path
# Out:
# c:\Users\Nguyen Giang\AppData\Local\Programs\Python\Python39\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
dir = Path(dir)
output_dir = Path(output_dir)

# %%
import os
path = "0000001.wav.wav"
basename = ".".join(path.split(".")[:-1])
basename
# Out:
# '0000001.wav'

# %%
import soundfile as sf
for path in os.listdir(dir):
    input_path = os.path.join(dir, path)
    print(input_path)
    basename = ".".join(path.split(".")[:-1])
    output_path = os.path.join(output_dir, basename)
    # print(output_path)
    audio, fs = sf.read(input_path)

    # Resample the audio to 24 kHz
    # audio = audio.set_frame_rate(24000)

    # Export the resampled audio
    sf.write(str(output_path), audio, 24000)
# Out:
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000001.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000003.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000004.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000006.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000020.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000044.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000055.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000056.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000057.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000058.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000060.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000061.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000062.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000063.wav.wav
# C:\Users\Nguyen Giang\Documents\ngochuyen_RVC\0000064.wav.wav
# ...

# %%
dir = "/kaggle/input/phuthang-24k/wav_normalized_3db_24k"
with open(r"C:\StyleTTS-test\Data\val_list_v2.txt", "r") as f:
    files = f.readlines()
    for line in files:
        cols = line.split("|")
        new_path = os.path.join(dir, os.path.basename(cols[0]))
        new_item = str(new_path) + "|" + cols[1] + "|" + cols[2] + "|" + cols[3]
        with open(r"C:\StyleTTS-test\Data\val_kaggle.txt", "a") as f:
            f.write(new_item)

# %%
wav_dir = os.listdir(Path(r"C:/ngochuyen_RVC_24k"))
with open(r'C:\StyleTTS-test\metadata_ngochuyen.txt', 'r') as f:
    files = f.readlines()
    for line in files:
        wav_path = os.path.basename(line.split("|")[0])
        if wav_path in wav_dir:
            with open("metadata_NH_RVC.txt", "a") as file:
                file.write(line)

# %%
wav_dir = os.listdir(Path(r"C:/ngochuyen_RVC_24k"))
